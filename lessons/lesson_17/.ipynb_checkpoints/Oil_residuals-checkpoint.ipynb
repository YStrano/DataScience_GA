# %% [markdown]
# # Analyzing Oil Markets using Residuals

# %% [markdown]
# Today we will be analyzing oil markets using the us dollar, industrial production (as a proxy for demand) and the vix

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
ip = pd.read_csv('data/oil/ip_oecd.csv') #industrial production is the predcitor of oil demand
vix = pd.read_csv('data/oil/vix.csv') #financial indicator for uncertainty or fear on the market
oil_usd = pd.read_csv('data/oil/oil_usd.csv')

# %% [markdown]
# ## Notice I have different frequencies throughout these datasets

# %%
## quarterly
ip.head()
# Out:
#          DATE  ip_oecd
# 0   3/31/1975    0.468
# 1   6/30/1975    0.462
# 2   9/30/1975    0.468
# 3  12/31/1975    0.477
# 4   3/31/1976    0.491

# %%
## monthly
oil_usd.head()
# Out:
#          DATE  oil      usd
# 0  1973-01-01  NaN  33.9689
# 1  1973-02-01  NaN  32.5799
# 2  1973-03-01  NaN  31.5849
# 3  1973-04-01  NaN  31.7681
# 4  1973-05-01  NaN  31.5727

# %%
## Daily
vix.head()
# Out:
#          DATE    vix
# 0  1990-01-02  17.24
# 1  1990-01-03  18.19
# 2  1990-01-04  19.22
# 3  1990-01-05  20.11
# 4  1990-01-08  20.26

# %% [markdown]
# ## Define a little function to convert the "DATE" column to datetime, resample to quarterly, and make it the index

# %%
def make_date_index(df):
    df['DATE'] = pd.to_datetime(df['DATE'])
    df.set_index('DATE', inplace=True)
    df = df.resample('Q').mean()
    return df

oil_usd = make_date_index(oil_usd)
vix = make_date_index(vix)
ip = make_date_index(ip)

# %%
ip.tail()
# Out:
#             ip_oecd
# DATE
# 2016-06-30    1.069
# 2016-09-30    1.071
# 2016-12-31    1.082
# 2017-03-31    1.088
# 2017-06-30    1.099

# %%
## Merge into our final data frame
df = oil_usd.join(ip)
df = df.join(vix)
df.head()
# Out:
#             oil        usd  ip_oecd  vix
# DATE
# 1973-03-31  NaN  32.711233      NaN  NaN
# 1973-06-30  NaN  31.475733      NaN  NaN
# 1973-09-30  NaN  30.896133      NaN  NaN
# 1973-12-31  NaN  31.735267      NaN  NaN
# 1974-03-31  NaN  32.788567      NaN  NaN

# %%
df.tail()
# Out:
#                   oil         usd  ip_oecd        vix
# DATE
# 2017-06-30  49.670000  123.283000    1.099  11.426349
# 2017-09-30  52.110000  119.120200      NaN  10.944286
# 2017-12-31  61.530000  120.093500      NaN  10.307937
# 2018-03-31  66.806667  117.636067      NaN  17.354754
# 2018-06-30  72.110000  120.694033      NaN  15.625200

# %%
df.plot()

# %% [markdown]
# issue with scale, to understand the data in graph

# %%
## Lets drop nulls
df.dropna(inplace=True)

# %%
## Lets take logs
df = df.apply(lambda x: np.log(x), axis=1)

# %%
df.plot()

# %%
## Lets take differences (now we are in log differences!)
df = df.apply(lambda x: x.diff())
df.plot()

# %%
df.corr()
# Out:
#               oil       usd   ip_oecd       vix
# oil      1.000000 -0.618317  0.418402 -0.251604
# usd     -0.618317  1.000000 -0.293694  0.289018
# ip_oecd  0.418402 -0.293694  1.000000 -0.037671
# vix     -0.251604  0.289018 -0.037671  1.000000

# %%
import statsmodels.formula.api as smf
lm = smf.ols('oil ~ usd + ip_oecd + vix', data= df).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    oil   R-squared:                       0.452
# Model:                            OLS   Adj. R-squared:                  0.436
# Method:                 Least Squares   F-statistic:                     28.82
# Date:                Wed, 13 Jun 2018   Prob (F-statistic):           1.12e-13
# Time:                        19:58:39   Log-Likelihood:                 77.890
# No. Observations:                 109   AIC:                            -147.8
# Df Residuals:                     105   BIC:                            -137.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0133      0.013      1.054      0.294      -0.012       0.038
# usd           -3.4120      0.525     -6.503      0.000      -4.452      -2.372
# ip_oecd        3.1230      0.896      3.487      0.001       1.347       4.899
# vix           -0.0777      0.063     -1.232      0.221      -0.203       0.047
# ==============================================================================
# Omnibus:                        4.072   Durbin-Watson:                   2.067
# Prob(Omnibus):                  0.131   Jarque-Bera (JB):                4.782
# Skew:                          -0.111   Prob(JB):                       0.0915
# Kurtosis:                       4.002   Cond. No.                         79.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Lets look at the Residuals

# %%
residuals = lm.resid

# %%
residuals.plot()

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(residuals)
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ## Key events in the oil market

# %% [markdown]
#  - March 1999: OPEC Production Cut
#  - 2010-2011: Arab Spring/ Libyan civil war
#  - 2015 - Present: reduction in oil investment due to shale boom

# %%
residuals.rolling(4).mean().plot()

# %% [markdown]
# this shows that log diff is very close to % change

# %%
np.log(100)-np.log(110)
# Out:
# -0.09531017980432477

# %%
(np.log(100)-np.log(110)) == (np.log(110)-np.log(100))
# Out:
# False

# %%
print((np.log(100)-np.log(110)), (np.log(110)-np.log(100)))
# Out:
# -0.09531017980432477 0.09531017980432477
