# %% [markdown]
# # Project 2
#
# In this project, you will implement the exploratory analysis plan developed in Project 1. This will lay the groundwork for our our first modeling exercise in Project 3.

# %% [markdown]
# ### Step 1: Load the python libraries you will need for this project

# %%
#imports
from __future__ import division
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pylab as pl
import numpy as np
# %matplotlib inline
# Out:
# C:\Users\ystrano\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ### Step 2: Read in your data set

# %%
#Read in data from source 
df_raw = pd.read_csv("../assets/admissions.csv")
print(df_raw.head())
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0

# %%
list(df_raw.columns)
# Out:
# ['admit', 'gre', 'gpa', 'prestige']

# %% [markdown]
# ## Questions
# #### Question 1. How many observations are in our dataset?

# %%
df_raw.count()
# Out:
# admit       400
# gre         398
# gpa         398
# prestige    399
# dtype: int64

# %% [markdown]
# Answer: 400+398+398+399 = 1595

# %% [markdown]
# #### Question 2. Create a summary table

# %%
#function

# %%
df_raw.info
# Out:
# <bound method DataFrame.info of      admit    gre   gpa  prestige
# 0        0  380.0  3.61       3.0
# 1        1  660.0  3.67       3.0
# 2        1  800.0  4.00       1.0
# 3        1  640.0  3.19       4.0
# 4        0  520.0  2.93       4.0
# 5        1  760.0  3.00       2.0
# 6        1  560.0  2.98       1.0
# 7        0  400.0  3.08       2.0
# 8        1  540.0  3.39       3.0
# 9        0  700.0  3.92       2.0
# 10       0  800.0  4.00       4.0
# 11       0  440.0  3.22       1.0
# 12       1  760.0  4.00       1.0
# 13       0  700.0  3.08       2.0
# 14       1  700.0  4.00       1.0
# 15       0  480.0  3.44       3.0
# 16       0  780.0  3.87       4.0
# 17       0  360.0  2.56       3.0
# 18       0  800.0  3.75       2.0
# 19       1  540.0  3.81       1.0
# 20       0  500.0  3.17       3.0
# 21       1  660.0  3.63       2.0
# 22       0  600.0  2.82       4.0
# 23       0  680.0  3.19       4.0
# 24       1  760.0  3.35       2.0
# 25       1  800.0  3.66       1.0
# 26       1  620.0  3.61       1.0
# 27       1  520.0  3.74       4.0
# 28       1  780.0  3.22       2.0
# 29       0  520.0  3.29       1.0
# ..     ...    ...   ...       ...
# 370      1  540.0  3.77       2.0
# 371      1  680.0  3.76       3.0
# 372      1  680.0  2.42       1.0
# 373      1  620.0  3.37       1.0
# 374      0  560.0  3.78       2.0
# 375      0  560.0  3.49       4.0
# 376      0  620.0  3.63       2.0
# 377      1  800.0  4.00       2.0
# 378      0  640.0  3.12       3.0
# 379      0  540.0  2.70       2.0
# 380      0  700.0  3.65       2.0
# 381      1  540.0  3.49       2.0
# 382      0  540.0  3.51       2.0
# 383      0  660.0  4.00       1.0
# 384      1  480.0  2.62       2.0
# 385      0  420.0  3.02       1.0
# 386      1  740.0  3.86       2.0
# 387      0  580.0  3.36       2.0
# 388      0  640.0  3.17       2.0
# 389      0  640.0  3.51       2.0
# 390      1  800.0  3.05       2.0
# 391      1  660.0  3.88       2.0
# 392      1  600.0  3.38       3.0
# 393      1  620.0  3.75       2.0
# 394      1  460.0  3.99       3.0
# 395      0  620.0  4.00       2.0
# 396      0  560.0  3.04       3.0
# 397      0  460.0  2.63       2.0
# 398      0  700.0  3.65       2.0
# 399      0  600.0  3.89       3.0
#
# [400 rows x 4 columns]>

# %%
df_raw.describe()
# Out:
#             admit         gre        gpa    prestige
# count  400.000000  398.000000  398.00000  399.000000
# mean     0.317500  588.040201    3.39093    2.486216
# std      0.466087  115.628513    0.38063    0.945333
# min      0.000000  220.000000    2.26000    1.000000
# 25%      0.000000  520.000000    3.13000    2.000000
# 50%      0.000000  580.000000    3.39500    2.000000
# 75%      1.000000  660.000000    3.67000    3.000000
# max      1.000000  800.000000    4.00000    4.000000

# %% [markdown]
# #### Question 3. Why would GRE have a larger STD than GPA?

# %% [markdown]
# Answer: the measure of units is larger so the STD will be much larger? (2.2 min to 4.0 max vs. 220 min to 800 max)

# %% [markdown]
# #### Question 4. Drop data points with missing data

# %%
new_df = df_raw.dropna()

# %% [markdown]
# #### Question 5. Confirm that you dropped the correct data. How can you tell?

# %%
new_df.count()
# Out:
# admit       397
# gre         397
# gpa         397
# prestige    397
# dtype: int64

# %% [markdown]
# Answer: `.count()` gives the same result for all columns

# %% [markdown]
# #### Question 6. Create box plots for GRE and GPA

# %%
#boxplot 1
plt.boxplot(new_df['gre'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0xb659128>],
#  'caps': [<matplotlib.lines.Line2D at 0xb659b38>,
#   <matplotlib.lines.Line2D at 0xb659f60>],
#  'fliers': [<matplotlib.lines.Line2D at 0xb77b7f0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0xb77b3c8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0xb659278>,
#   <matplotlib.lines.Line2D at 0xb659710>]}

# %%
#boxplot 2 
plt.boxplot(new_df['gpa'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0xb48bc88>],
#  'caps': [<matplotlib.lines.Line2D at 0xb48b4e0>,
#   <matplotlib.lines.Line2D at 0xb486c88>],
#  'fliers': [<matplotlib.lines.Line2D at 0xb46fbe0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0xb480898>],
#  'whiskers': [<matplotlib.lines.Line2D at 0xb48ba90>,
#   <matplotlib.lines.Line2D at 0xb48b550>]}

# %% [markdown]
# #### Question 7. What do this plots show?

# %% [markdown]
# Answer:

# %% [markdown]
# #### Question 8. Describe each distribution

# %%
# plot the distribution of each variable

# %%
plt.plot(new_df['admit'])

# %%
plt.plot(new_df['gre'])

# %%
plt.plot(new_df['gpa'])

# %%
plt.plot(new_df['prestige'])

# %% [markdown]
# #### Question 9.  If our model had an assumption of a normal distribution would we meet that requirement?

# %% [markdown]
# Answer:

# %% [markdown]
# #### Question 10.  Does this distribution need correction? If so, why? How?

# %% [markdown]
# Answer: logarithm

# %% [markdown]
# #### Question 11. Which of our variables are potentially colinear?

# %%
# create a correlation matrix for the data
new_df.corr()
# Out:
#              admit       gre       gpa  prestige
# admit     1.000000  0.181202  0.174116 -0.243563
# gre       0.181202  1.000000  0.382408 -0.124533
# gpa       0.174116  0.382408  1.000000 -0.060976
# prestige -0.243563 -0.124533 -0.060976  1.000000

# %% [markdown]
# #### Question 12. What did you find?

# %% [markdown]
# Answer: GPA and GRE

# %% [markdown]
# #### Question 13. Write an analysis plan for exploring the association between grad school admissions rates and prestige of  undergraduate schools.

# %% [markdown]
# Answer:

# %% [markdown]
# #### Question 14. What is your hypothesis?

# %% [markdown]
# Answer: remember null hypothesis

# %% [markdown]
# ## Bonus/Advanced

# %% [markdown]
# #### 1. Bonus: Explore alternatives to dropping obervations with missing data

# %% [markdown]
# #### 2. Bonus: Log transform the skewed data

# %% [markdown]
# #### 3. Advanced: Impute missing data
